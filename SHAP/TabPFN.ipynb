# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from tabpfn import TabPFNClassifier
import shap
import matplotlib.pyplot as plt

# %%
seed = 873465341

# %%
data = pd.read_csv('data_SHAP.csv')
X = data.iloc[:,2:]
y = data.iloc[:,1]

# %%
model = TabPFNClassifier(random_state=seed)
model.fit(X,y)
# Out:
# TabPFNClassifier(random_state=873465341)

# %%
def func(X):
  return model.predict_proba(X)[:,1]

# %%
explainer = shap.KernelExplainer(func,shap.sample(X,nsamples=20,random_state=seed))
shap_values = explainer.shap_values(X)

# %%
pd.DataFrame(shap_values).to_csv('SHAP_values.csv',index=False)

# %%
shap_values = np.array(pd.read_csv('SHAP_values.csv'))

# %%
X.columns
# Out:
# Index(['RECQL4', 'GPT2', 'SPP1', 'ADM2', 'C1QTNF6', 'STX1A', 'ARHGEF16',
#        'ZNF692', 'CLEC3B', 'HBB', 'CD300C', 'LAMP3', 'MSR1', 'VSIG4'],
#       dtype='object')

# %%
plt.figure(dpi=300)
shap.dependence_plot('RECQL4',shap_values,X,show=False)
plt.savefig('TabPFN_RECQL4.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('GPT2',shap_values,X,show=False)
plt.savefig('TabPFN_GPT2.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('SPP1',shap_values,X,show=False,interaction_index='HBB')
plt.savefig('TabPFN_SPP1.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('ADM2',shap_values,X,show=False)
plt.savefig('TabPFN_ADM2.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('C1QTNF6',shap_values,X,show=False)
plt.savefig('TabPFN_C1QTNF6.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('STX1A',shap_values,X,show=False)
plt.savefig('TabPFN_STX1A.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('ARHGEF16',shap_values,X,show=False)
plt.savefig('TabPFN_ARHGEF16.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('ZNF692',shap_values,X,show=False)
plt.savefig('TabPFN_ZNF692.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('CLEC3B',shap_values,X,show=False)
plt.savefig('TabPFN_CLEC3B.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('HBB',shap_values,X,show=False)
plt.savefig('TabPFN_HBB.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('CD300C',shap_values,X,show=False)
plt.savefig('TabPFN_CD300C.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('LAMP3',shap_values,X,show=False)
plt.savefig('TabPFN_LAMP3.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('MSR1',shap_values,X,show=False)
plt.savefig('TabPFN_MSR1.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=300)
shap.dependence_plot('VSIG4',shap_values,X,show=False)
plt.savefig('TabPFN_VSIG4.png',dpi=600,bbox_inches='tight')

# %%
plt.figure(dpi=600)
shap.summary_plot(shap_values,X,plot_type='bar',show=False)
plt.savefig('Bar.png')
plt.show()

# %%
plt.figure(dpi=600)
shap.summary_plot(shap_values,X,show=False)
plt.savefig('TabPFN_importance.png')
plt.show()
